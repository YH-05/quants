# %%
from market.etfcom import TickerCollector
import pandas as pd
from IPython.display import display
from market.etfcom.types import ScrapingConfig

# %%
collector = TickerCollector(config=ScrapingConfig(timeout=600.0, headless=False))
df = await collector._async_fetch()
display(df)
# Out:
# [error    ] Navigation failed              [market.etfcom.browser] error='Page.goto: Target page, context or browser has been closed\nCall log:\n  - navigating to "https://www.etf.com/topics/etf-screener", waiting until "networkidle"\n' url=https://www.etf.com/topics/etf-screener
# ---------------------------------------------------------------------------
# TargetClosedError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 collector = TickerCollector(config=ScrapingConfig(timeout=600.0, headless=False))
# ----> 2 df = await collector._async_fetch()
#       3 display(df)
#
# File ~/Desktop/finance/src/market/etfcom/collectors.py:232, in TickerCollector._async_fetch(self, **kwargs)
#     230 # Navigate to screener page
#     231 logger.info("Navigating to screener page", url=SCREENER_URL)
# --> 232 page = await browser._navigate(SCREENER_URL)
#     234 # Accept cookie consent
#     235 await browser._accept_cookies(page)
#
# File ~/Desktop/finance/src/market/etfcom/browser.py:312, in ETFComBrowserMixin._navigate(self, url, wait_until)
#     309 timeout_ms = self._config.timeout * 1000
#     311 try:
# --> 312     await page.goto(url, timeout=timeout_ms, wait_until=wait_until)
#     313     logger.debug(
#     314         "Navigation completed",
#     315         url=url,
#     316         wait_until=wait_until,
#     317     )
#     318     return page
#
# File ~/Desktop/finance/.venv/lib/python3.12/site-packages/playwright/async_api/_generated.py:9041, in Page.goto(self, url, timeout, wait_until, referer)
#    8980 async def goto(
#    8981     self,
#    8982     url: str,
#    (...)   8988     referer: typing.Optional[str] = None,
#    8989 ) -> typing.Optional["Response"]:
#    8990     """Page.goto
#    8991
#    8992     Returns the main resource response. In case of multiple redirects, the navigation will resolve with the first
#    (...)   9037     Union[Response, None]
#    9038     """
#    9040     return mapping.from_impl_nullable(
# -> 9041         await self._impl_obj.goto(
#    9042             url=url, timeout=timeout, waitUntil=wait_until, referer=referer
#    9043         )
#    9044     )
#
# File ~/Desktop/finance/.venv/lib/python3.12/site-packages/playwright/_impl/_page.py:552, in Page.goto(self, url, timeout, waitUntil, referer)
#     545 async def goto(
#     546     self,
#     547     url: str,
#    (...)    550     referer: str = None,
#     551 ) -> Optional[Response]:
# --> 552     return await self._main_frame.goto(**locals_to_params(locals()))
#
# File ~/Desktop/finance/.venv/lib/python3.12/site-packages/playwright/_impl/_frame.py:153, in Frame.goto(self, url, timeout, waitUntil, referer)
#     143 async def goto(
#     144     self,
#     145     url: str,
#    (...)    148     referer: str = None,
#     149 ) -> Optional[Response]:
#     150     return cast(
#     151         Optional[Response],
#     152         from_nullable_channel(
# --> 153             await self._channel.send(
#     154                 "goto", self._navigation_timeout, locals_to_params(locals())
#     155             )
#     156         ),
#     157     )
#
# File ~/Desktop/finance/.venv/lib/python3.12/site-packages/playwright/_impl/_connection.py:69, in Channel.send(self, method, timeout_calculator, params, is_internal, title)
#      61 async def send(
#      62     self,
#      63     method: str,
#    (...)     67     title: str = None,
#      68 ) -> Any:
# ---> 69     return await self._connection.wrap_api_call(
#      70         lambda: self._inner_send(method, timeout_calculator, params, False),
#      71         is_internal,
#      72         title,
#      73     )
#
# File ~/Desktop/finance/.venv/lib/python3.12/site-packages/playwright/_impl/_connection.py:559, in Connection.wrap_api_call(self, cb, is_internal, title)
#     557     return await cb()
#     558 except Exception as error:
# --> 559     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     560 finally:
#     561     self._api_zone.set(None)
#
# TargetClosedError: Page.goto: Target page, context or browser has been closed
# Call log:
#   - navigating to "https://www.etf.com/topics/etf-screener", waiting until "networkidle"
