# %%
from news_scraper import collect_financial_news, collect_financial_news_fast, ScraperConfig
import pandas as pd

import trafilatura
from trafilatura import fetch_url

# %%
df = collect_financial_news(config=ScraperConfig(include_content=True))

# %%
display(df)
# Out:
#                                                  title  \
# 0    Are Jack Dorsey's aggressive job cuts the star...
# 1    Core wholesale prices rose 0.8% in January, mu...
# 2    Trump insists trade deals safe after Supreme C...
# 3    Top earners are more afraid for their employme...
# 4    China’s leverage rises before high-stakes summ...
# ..                                                 ...
# 328                          Hogs Ease Lower on Friday
# 329                    Hogs Posting Mixed Friday Trade
# 330                     Upcoming Dividend Run For ARR?
# 331  Canada Goose Holdings (TSX:GOOS) Price Target ...
# 332  ST Pharm Co. (KOSDAQ:237690) Price Target Incr...
#
#                                                    url  \
# 0    https://www.cnbc.com/2026/02/27/are-dorseys-gi...
# 1    https://www.cnbc.com/2026/02/27/ppi-january-20...
# 2    https://www.cnbc.com/2026/02/26/trump-state-of...
# 3    https://www.cnbc.com/2026/02/25/top-earners-ar...
# ...
