# %%
from market.bloomberg import fetcher
import pandas as pd 
from pathlib import Path 
from utils_core.config import ProjectConfig

config = ProjectConfig.from_env()

# %%
list_portfolio = config.data_dir / ""
