# %%
from market import bloomberg
import pandas as pd
from datetime import datetime

# %%
blp = bloomberg.BloombergFetcher()
bbg_options = bloomberg.BloombergFetchOptions(securities=['AAPL US EQUITY', 'MSFT US EQUITY', 'LLY US EQUITY'], fields=['PX_LAST'], start_date='2015-11-30', end_date=datetime.today())
data = blp.get_historical_data(bbg_options)
display(data)
# Out:
# 26FEB2026_17:21:15.679 57770:6289960960 WARN apicm_apiconnector.cpp:385 ApiConnector::socketConnectorCallback localhost: Failed to connect to 127.0.0.1:8194, status=1, error 8 connect event failed
#
# 26FEB2026_17:21:15.679 57770:6289960960 WARN blpapi_platformtransporttcp.cpp:140 blpapi.session.{1}.transporttcp<0><localhost:8194> 127.0.0.1, session pool state=Failed
#
# 26FEB2026_17:21:18.632 57770:6289960960 WARN apicm_apiconnector.cpp:385 ApiConnector::socketConnectorCallback localhost: Failed to connect to 127.0.0.1:8194, status=1, error 8 connect event failed
#
# 26FEB2026_17:21:18.632 57770:6289960960 WARN blpapi_platformtransporttcp.cpp:140 blpapi.session.{1}.transporttcp<0><localhost:8194> 127.0.0.1, session pool state=Failed
#
# 26FEB2026_17:21:23.487 57770:6289960960 WARN apicm_apiconnector.cpp:385 ApiConnector::socketConnectorCallback localhost: Failed to connect to 127.0.0.1:8194, status=1, error 8 connect event failed
#
# ...
